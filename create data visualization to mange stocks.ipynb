# %% [markdown]
# # importing library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # getting all stocks csv data files

# %%
import os
path = "stocks-2000-2020"
dir_list = os.listdir(path)
print("Files and directories in", path, "' :")
print(dir_list)
# Out:
# Files and directories in stocks-2000-2020 ' :
# ['ADANIPORTS.csv', 'ASIANPAINT.csv', 'AXISBANK.csv', 'BAJAJ-AUTO.csv', 'BAJAJFINSV.csv', 'BAJFINANCE.csv', 'BHARTIARTL.csv', 'BPCL.csv', 'BRITANNIA.csv', 'CIPLA.csv', 'COALINDIA.csv', 'DRREDDY.csv', 'EICHERMOT.csv', 'GAIL.csv', 'GRASIM.csv', 'HCLTECH.csv', 'HDFC.csv', 'HDFCBANK.csv', 'HEROMOTOCO.csv', 'HINDALCO.csv', 'HINDUNILVR.csv', 'ICICIBANK.csv', 'INDUSINDBK.csv', 'INFRATEL.csv', 'INFY.csv', 'IOC.csv', 'ITC.csv', 'JSWSTEEL.csv', 'KOTAKBANK.csv', 'LT.csv', 'MARUTI.csv', 'MM.csv', 'NESTLEIND.csv', 'NIFTY50_all.csv', 'NTPC.csv', 'ONGC.csv', 'POWERGRID.csv', 'RELIANCE.csv', 'SBIN.csv', 'SHREECEM.csv', 'stock_metadata.csv', 'SUNPHARMA.csv', 'TATAMOTORS.csv', 'TATASTEEL.csv', 'TCS.csv', 'TECHM.csv', 'TITAN.csv', 'ULTRACEMCO.csv', 'UPL.csv', 'VEDL.csv', 'WIPRO.csv', 'ZEEL.csv']

# %% [markdown]
# # printing all stocks csv files below

# %%
for i in dir_list:
    print(i)
# Out:
# ADANIPORTS.csv
# ASIANPAINT.csv
# AXISBANK.csv
# BAJAJ-AUTO.csv
# BAJAJFINSV.csv
# BAJFINANCE.csv
# BHARTIARTL.csv
# BPCL.csv
# BRITANNIA.csv
# CIPLA.csv
# COALINDIA.csv
# DRREDDY.csv
# EICHERMOT.csv
# GAIL.csv
# GRASIM.csv
# HCLTECH.csv
# HDFC.csv
# HDFCBANK.csv
# HEROMOTOCO.csv
# HINDALCO.csv
# HINDUNILVR.csv
# ICICIBANK.csv
# INDUSINDBK.csv
# INFRATEL.csv
# INFY.csv
# IOC.csv
# ITC.csv
# JSWSTEEL.csv
# KOTAKBANK.csv
# LT.csv
# MARUTI.csv
# MM.csv
# NESTLEIND.csv
# NIFTY50_all.csv
# NTPC.csv
# ONGC.csv
# POWERGRID.csv
# RELIANCE.csv
# SBIN.csv
# SHREECEM.csv
# stock_metadata.csv
# SUNPHARMA.csv
# TATAMOTORS.csv
# TATASTEEL.csv
# TCS.csv
# TECHM.csv
# TITAN.csv
# ULTRACEMCO.csv
# UPL.csv
# VEDL.csv
# WIPRO.csv
# ZEEL.csv

# %% [markdown]
# # entering stock file name

# %%
print("enter your company stock file name{it is case sensitive be carefull}:")
file_name=input()
# Out:
# enter your company stock file name{it is case sensitive be carefull}:
# ZEEL.csv

# %% [markdown]
# # loading stock data from csv files u given

# %%
file_path_name="stocks-2000-2020/"+file_name
df=pd.read_csv(file_path_name)

# %%
df
# Out:
#             Date   Symbol Series  Prev Close     Open     High      Low  \
# 0     2000-01-03  ZEETELE     EQ     1092.55  1175.00  1179.95  1160.00
# 1     2000-01-04  ZEETELE     EQ     1179.95  1220.00  1274.35  1183.10
# 2     2000-01-05  ZEETELE     EQ     1260.65  1160.55  1317.70  1159.80
# 3     2000-01-06  ZEETELE     EQ     1176.55  1195.00  1200.00  1095.00
# 4     2000-01-07  ZEETELE     EQ     1115.45  1097.10  1097.10  1026.25
# ...          ...      ...    ...         ...      ...      ...      ...
# 5301  2021-04-26     ZEEL     EQ      188.00   190.60   191.10   185.10
# 5302  2021-04-27     ZEEL     EQ      186.40   188.00   192.95   186.80
# 5303  2021-04-28     ZEEL     EQ      188.15   188.80   190.60   187.10
# 5304  2021-04-29     ZEEL     EQ      189.10   190.80   191.65   186.00
# 5305  2021-04-30     ZEEL     EQ      186.55   185.30   190.95   183.65
#
#          Last    Close     VWAP    Volume      Turnover   Trades  \
# ...

# %% [markdown]
# # droping NaN values from the dataframe

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 2850  2011-06-01   ZEEL     EQ      137.10  135.20  140.50  135.20  140.00
# 2851  2011-06-02   ZEEL     EQ      139.75  138.00  143.70  136.60  143.00
# 2852  2011-06-03   ZEEL     EQ      143.05  144.00  144.60  139.30  141.00
# 2853  2011-06-06   ZEEL     EQ      140.25  140.25  142.80  138.15  140.10
# 2854  2011-06-07   ZEEL     EQ      140.00  140.90  145.70  138.10  144.30
# ...          ...    ...    ...         ...     ...     ...     ...     ...
# 5301  2021-04-26   ZEEL     EQ      188.00  190.60  191.10  185.10  186.70
# 5302  2021-04-27   ZEEL     EQ      186.40  188.00  192.95  186.80  188.80
# 5303  2021-04-28   ZEEL     EQ      188.15  188.80  190.60  187.10  188.95
# 5304  2021-04-29   ZEEL     EQ      189.10  190.80  191.65  186.00  186.60
# 5305  2021-04-30   ZEEL     EQ      186.55  185.30  190.95  183.65  185.00
#
# ...

# %% [markdown]
# # droping unwanted columns

# %%
df1=df.drop(columns=['Symbol','Series','Prev Close','Close','VWAP','Trades','Deliverable Volume','%Deliverble'])

# %%
df1
# Out:
#             Date    Open    High     Low    Last    Volume      Turnover
# 2850  2011-06-01  135.20  140.50  135.20  140.00   1389136  1.920766e+13
# 2851  2011-06-02  138.00  143.70  136.60  143.00   3440731  4.884936e+13
# 2852  2011-06-03  144.00  144.60  139.30  141.00   1456839  2.062902e+13
# 2853  2011-06-06  140.25  142.80  138.15  140.10   1056270  1.480649e+13
# 2854  2011-06-07  140.90  145.70  138.10  144.30   1900712  2.718152e+13
# ...          ...     ...     ...     ...     ...       ...           ...
# 5301  2021-04-26  190.60  191.10  185.10  186.70   8542755  1.600451e+14
# 5302  2021-04-27  188.00  192.95  186.80  188.80  14247767  2.698636e+14
# 5303  2021-04-28  188.80  190.60  187.10  188.95   8429439  1.591917e+14
# 5304  2021-04-29  190.80  191.65  186.00  186.60   9483009  1.777471e+14
# 5305  2021-04-30  185.30  190.95  183.65  185.00  11435285  2.144440e+14
#
# [2456 rows x 7 columns]

# %% [markdown]
# # visualization of stock dataset from library

# %%
import matplotlib.pyplot as plt
df1.plot(subplots=True, figsize=(7,7)); plt.legend(loc='best')

# %% [markdown]
# # Thank You

# %% [markdown]
# # Team lead Mallayya Mathapati CSIT-A
# # Team member Jeshik s CSIT-A
